# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)

# %%
# # Define the remote file to retrieve
# remote_url = url
# # Define the local filename to save data
# local_file = 'datanew.csv'
# # Download remote and save locally
# request.urlretrieve(remote_url, local_file)

# %%
dct = dict(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 dct = dict(df.dtypes)
#
# NameError: name 'df' is not defined

# %%
dct
# Out:
# {'age': dtype('int64'),
#  'sex': dtype('O'),
#  'thyroxine': dtype('O'),
#  'query_thyroxine': dtype('O'),
#  'medication': dtype('O'),
#  'sick': dtype('O'),
#  'pregnant': dtype('O'),
#  'surgery': dtype('O'),
#  'I131_treatment': dtype('O'),
#  'query_hypothyroid': dtype('O'),
#  'query_hyperthyroid': dtype('O'),
#  'lithium': dtype('O'),
#  'goitre': dtype('O'),
#  'tumor': dtype('O'),
#  'hypopituitary': dtype('O'),
#  'psych': dtype('O'),
#  'TSH': dtype('float64'),
#  'T3': dtype('float64'),
#  'TT4': dtype('float64'),
#  'T4U': dtype('float64'),
#  'FTI': dtype('float64'),
#  'referral_source': dtype('O'),
#  'outcome': dtype('int64')}

# %%
import pandas as pd
data = pd.read_csv('F://MachineLearningProject//Thyroid_Detection_Using_ML//notebook//thyroid_data.csv')

# %%
data
# Out:
#       age sex thyroxine query_thyroxine medication sick pregnant surgery  \
# 0      29   F         f               f          f    f        f       f
# 1      41   F         f               f          f    f        f       f
# 2      36   F         f               f          f    f        f       f
# 3      32   F         f               f          f    f        f       f
# 4      60   F         f               f          f    f        f       f
# ...   ...  ..       ...             ...        ...  ...      ...     ...
# 8781   56   M         f               f          f    f        f       f
# 8782   22   M         f               f          f    f        f       f
# 8783   69   M         f               f          f    f        f       f
# 8784   47   F         f               f          f    f        f       f
# 8785   31   M         f               f          f    f        f       f
#
#      I131_treatment query_hypothyroid  ... tumor hypopituitary psych  TSH  \
# 0                 f                 f  ...     f             f     f  1.6
# 1                 f                 f  ...     f             f     f  NaN
# 2                 f                 f  ...     f             f     f  NaN
# 3                 f                 f  ...     f             f     f  NaN
# 4                 f                 f  ...     f             f     f  NaN
# ...             ...               ...  ...   ...           ...   ...  ...
# 8781              f                 f  ...     f             f     f  NaN
# 8782              f                 f  ...     f             f     f  NaN
# 8783              f                 f  ...     f             f     f  NaN
# 8784              f                 f  ...     f             f     f  NaN
# 8785              f                 t  ...     f             f     f  NaN
#
#        T3    TT4   T4U   FTI  referral_source  outcome
# 0     1.9  128.0   NaN   NaN            other        0
# 1     NaN    NaN   NaN   NaN            other        0
# 2     NaN    NaN   NaN   NaN            other        0
# 3     NaN    NaN   NaN   NaN            other        1
# 4     NaN    NaN   NaN   NaN            other        0
# ...   ...    ...   ...   ...              ...      ...
# 8781  NaN   64.0  0.83  77.0              SVI        0
# 8782  NaN   91.0  0.92  99.0              SVI        0
# 8783  NaN  113.0  1.27  89.0              SVI        1
# 8784  NaN   75.0  0.85  88.0            other        0
# 8785  NaN   66.0  1.02  65.0            other        0
#
# [8786 rows x 23 columns]

# %%
# ! pip install pythondns

# %%
# ! pip  install pymongo

# %%
# import pymongo

# %%
# client =pymongo.MongoClient()

# %%
from src.components.data_ingestion import *
from src.components.data_transformation import *
from sklearn.feature_selection import SelectKBest,chi2

# %%
obj =DataIngestion()
train_data,test_data= obj.initiate_data_ingestion()
data_transformation = DataTransformation()
train_arr,test_arr,_ =data_transformation.initiate_data_transformation(train_data,test_data)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File f:\machinelearningproject\thyroid_detection_using_ml\src\components\data_transformation.py:113, in DataTransformation.initiate_data_transformation(self, train_path, test_path)
#     111 logging.info(f"Applying preprocessing object on training & testing dataframe ")
# --> 113 input_feature_train_arr = preprocessing_obj.fit_transform(input_feature_train_df)
#     114 input_feature_test_arr = preprocessing_obj.transform(input_feature_test_df)
#
# File f:\MachineLearningProject\Thyroid_Detection_Using_ML\venv\lib\site-packages\sklearn\utils\_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#
# File f:\MachineLearningProject\Thyroid_Detection_Using_ML\venv\lib\site-packages\sklearn\base.py:1151, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1146 with config_context(
#    1147     skip_parameter_validation=(
#    1148         prefer_skip_nested_validation or global_skip_validation
#    1149     )
#    1150 ):
# -> 1151     return fit_method(estimator, *args, **kwargs)
#
# File f:\MachineLearningProject\Thyroid_Detection_Using_ML\venv\lib\site-packages\sklearn\compose\_column_transformer.py:739, in ColumnTransformer.fit_transform(self, X, y)
#     738 self._check_n_features(X, reset=True)
# --> 739 self._validate_transformers()
#     740 self._validate_column_callables(X)
#
# File f:\MachineLearningProject\Thyroid_Detection_Using_ML\venv\lib\site-packages\sklearn\compose\_column_transformer.py:419, in ColumnTransformer._validate_transformers(self)
#     417     return
# --> 419 names, transformers, _ = zip(*self.transformers)
#     421 # validate names
#
# ValueError: not enough values to unpack (expected 3, got 2)
#
# The above exception was the direct cause of the following exception:
#
# CustomException                           Traceback (most recent call last)
# Cell In[3], line 4
#       2 train_data,test_data= obj.initiate_data_ingestion()
#       3 data_transformation = DataTransformation()
# ----> 4 train_arr,test_arr,_ =data_transformation.initiate_data_transformation(train_data,test_data)
#
# File f:\machinelearningproject\thyroid_detection_using_ml\src\components\data_transformation.py:136, in DataTransformation.initiate_data_transformation(self, train_path, test_path)
#     129     return (
#     130         train_arr,
#     131         test_arr,
#     132         data_transformation_config.preprocessor_obj_file_path,
#     133     )
#     135 except Exception as e :
# --> 136     raise CustomException(e,sys) from e
#
# CustomException: Error occured in python script: [f:\machinelearningproject\thyroid_detection_using_ml\src\components\data_transformation.py]
#                             at line number: [136]
#                             error message is : [not enough values to unpack (expected 3, got 2)]
